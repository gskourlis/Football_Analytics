# %% [markdown]
# ### FBREF.com Web Scraping

# %%
import pandas as pd

# %%
df = pd.read_html('https://fbref.com/en/comps/8/2022-2023/2022-2023-Champions-League-Stats',
                 attrs = {"id":"results2022-202380_overall"})[0]

# %%
df = df.dropna(subset = ['Rk'])
df.head()
# Out:
#    Rk                Squad    MP    W    D    L    GF    GA    GD   Pts    xG  \
# 0   1  eng Manchester City  13.0  8.0  5.0  0.0  32.0   5.0  27.0  29.0  26.5
# 2   2             it Inter  13.0  7.0  3.0  3.0  19.0  11.0   8.0  24.0  17.9
# 4  SF       es Real Madrid  12.0  8.0  2.0  2.0  26.0  13.0  13.0  26.0  22.3
# 5  SF             it Milan  12.0  5.0  3.0  4.0  15.0  11.0   4.0  18.0  16.5
# 7  QF     de Bayern Munich  10.0  8.0  1.0  1.0  22.0   6.0  16.0  25.0  19.4
#
#     xGA   xGD  xGD/90  Attendance                           Top Team Scorer  \
# 0  10.5  16.0    1.23     63639.0                       Erling Haaland - 12
# 2  15.1   2.8    0.22     71415.0                            Edin Džeko - 4
# 4  15.9   6.4    0.53     58761.0                       Vinicius Júnior - 7
# 5  14.6   1.9    0.16     72546.0                        Olivier Giroud - 5
# 7  10.9   8.4    0.84     75000.0  Leroy Sané, Eric Maxim Choupo-Moting - 4
#
#          Goalkeeper  Notes
# ...

# %%
df = pd.read_html('https://fbref.com/en/squads/822bd0ba/2022-2023/Liverpool-Stats', 
                  attrs ={"id":"stats_standard_9"})[0]

# %%
df.head()
